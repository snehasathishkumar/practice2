# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
import wikipediaapi
import google.generativeai as genai
import PyPDF2
from langchain_community.document_loaders import WebBaseLoader
import requests
from bs4 import BeautifulSoup
from langchain.llms import Ollama
from langchain_community.embeddings import OllamaEmbeddings
from langchain_chroma import Chroma
import dotenv

# %%
api_key = dotenv.get_key(".env" , key_to_get="GEMINI_API_KEY")
genai.configure(api_key=api_key)

# %%
gen_config = genai.GenerationConfig(temperature=0.4)
model = genai.GenerativeModel( "models/gemini-1.5-flash" , generation_config=gen_config )

# %%
weburl = "https://www.gov.uk/government/publications/research-on-the-cyber-security-of-ai/ai-cyber-security-survey-main-report"
loader = WebBaseLoader(weburl)
loader.requests_kwargs = {'verify':False}
data = loader.load()
# Out:
# c:\Users\99013031\Desktop\urlsumm\.venv\Lib\site-packages\urllib3\connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.gov.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
data = str(data)

# %%
data
# Out:
# "[Document(page_content='\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n      AI cyber security survey - main report  - GOV.UK\\n  \\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\nCookies on GOV.UK\\n\\nWe use some essential cookies to make this website work.\\nWe’d like to set additional cookies to understand how you use GOV.UK, remember your settings and improve government services.\\nWe also use cookies set by other sites to help us deliver content from their services.\\nYou have accepted additional cookies. You can change your cookie settings at any time.\\nYou have rejected additional cookies. You can change your cookie settings at any time.\\n\\n\\n\\n\\nAccept additional cookies\\nReject additional cookies\\nView cookies\\n\\n\\n\\n          Hide this message\\n        \\n\\n\\n\\nSkip to main content\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n \\n\\n\\n                GOV.UK\\n              \\n\\n\\n \\n\\n\\n        Navigation menu\\n      \\n\\n\\n\\n                Menu\\n\\n\\nMenu\\n \\n\\n\\n\\n                Search GOV.UK\\n              \\n\\n\\n\\n\\n\\n                ×\\n              \\n\\n\\n\\n                Search GOV.UK\\n              \\n\\n\\n\\n\\n \\n \\n\\n\\n\\n\\n\\n                  Services and information\\n                \\n\\n\\nBenefits\\n\\n\\nBirths, death, marriages and care\\n\\n\\nBusiness and self-employed\\n\\n\\nChildcare and parenting\\n\\n\\nCitizenship and living in the UK\\n\\n\\nCrime, justice and the law\\n\\n\\nDisabled people\\n\\n\\nDriving and transport\\n\\n\\nEducation and learning\\n\\n\\nEmploying people\\n\\n\\nEnvironment and countryside\\n\\n\\nHousing and local services\\n\\n\\nMoney and tax\\n\\n\\nPassports, travel and living abroad\\n\\n\\nVisas and immigration\\n\\n\\nWorking, jobs and pensions\\n\\n\\n\\n\\n\\n                  Government activity\\n                \\n\\n\\nDepartments\\nDepartments, agencies and public bodies\\n\\n\\nNews\\nNews stories, speeches, letters and notices\\n\\n\\nGuidance and regulation\\nDetailed guidance, regulations and rules\\n\\n\\nResearch and statistics\\nReports, analysis and official statistics\\n\\n\\nPolicy papers and consultations\\nConsultations and strategy\\n\\n\\nTransparency\\nData, Freedom of Information releases and corporate reports\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n            Search\\n          \\n\\n\\n\\n\\nSearch GOV.UK\\n\\n\\n\\n\\n        Search\\n        \\n\\n\\n\\n\\n \\n\\n\\n\\n\\n\\n\\n \\n\\n\\n\\n\\n\\n\\n\\n\\n\\nRegister to vote\\n\\n          Register by 18 June to vote in the General Election on 4 July.\\n        \\n\\n\\n\\n\\n\\n\\n\\n\\n\\nHome\\n\\n\\nBusiness and industry\\n\\n\\nScience and innovation\\n\\n\\nArtificial intelligence\\n\\n\\nResearch on the cyber security of AI\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\nDepartment forScience, Innovation& Technology\\n\\n\\n\\n\\n\\n\\n\\n\\n    Research and analysis\\n  \\n\\n    AI cyber security survey - main report \\n  \\n\\nPublished 15 May 2024\\n\\n\\n\\n\\n\\n\\n      Contents\\n\\n\\n\\n\\n1. Executive summary\\n\\n\\n\\n2. Introduction\\n\\n\\n\\n3. Methodology\\n\\n\\n\\n4. AI usage\\n\\n\\n\\n5. Cyber security practices around AI\\n\\n\\n\\n6. General cyber security practices\\n\\n\\n\\n7. Appendix: Glossary\\n\\n\\n\\n\\nPrint this page\\n\\n\\n\\n\\n\\n\\n\\n\\n  © Crown copyright 2024\\n\\n\\n  This publication is licensed under the terms of the Open Government Licence v3.0 except where otherwise stated. To view this licence, visit nationalarchives.gov.uk/doc/open-government-licence/version/3 or write to the Information Policy Team, The National Archives, Kew, London TW9 4DU, or email: psi@nationalarchives.gov.uk.\\n\\n\\n  Where we have identified any third party copyright information you will need to obtain permission from the copyright holders concerned.\\n\\n\\n  This publication is available at https://www.gov.uk/government/publications/research-on-the-cyber-se ...

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100000, 
    chunk_overlap=30,
    separators=['.','\n','\n\n']
)

# %%
texts = text_splitter.split_text(data)

# %%
texts
# Out:
# ["[Document(page_content='\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n      AI cyber security survey - main report  - GOV.UK\\n  \\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\nCookies on GOV.UK\\n\\nWe use some essential cookies to make this website work.\\nWe’d like to set additional cookies to understand how you use GOV.UK, remember your settings and improve government services.\\nWe also use cookies set by other sites to help us deliver content from their services.\\nYou have accepted additional cookies. You can change your cookie settings at any time.\\nYou have rejected additional cookies. You can change your cookie settings at any time.\\n\\n\\n\\n\\nAccept additional cookies\\nReject additional cookies\\nView cookies\\n\\n\\n\\n          Hide this message\\n        \\n\\n\\n\\nSkip to main content\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n \\n\\n\\n                GOV.UK\\n              \\n\\n\\n \\n\\n\\n        Navigation menu\\n      \\n\\n\\n\\n                Menu\\n\\n\\nMenu\\n \\n\\n\\n\\n                Search GOV.UK\\n              \\n\\n\\n\\n\\n\\n                ×\\n              \\n\\n\\n\\n                Search GOV.UK\\n              \\n\\n\\n\\n\\n \\n \\n\\n\\n\\n\\n\\n                  Services and information\\n                \\n\\n\\nBenefits\\n\\n\\nBirths, death, marriages and care\\n\\n\\nBusiness and self-employed\\n\\n\\nChildcare and parenting\\n\\n\\nCitizenship and living in the UK\\n\\n\\nCrime, justice and the law\\n\\n\\nDisabled people\\n\\n\\nDriving and transport\\n\\n\\nEducation and learning\\n\\n\\nEmploying people\\n\\n\\nEnvironment and countryside\\n\\n\\nHousing and local services\\n\\n\\nMoney and tax\\n\\n\\nPassports, travel and living abroad\\n\\n\\nVisas and immigration\\n\\n\\nWorking, jobs and pensions\\n\\n\\n\\n\\n\\n                  Government activity\\n                \\n\\n\\nDepartments\\nDepartments, agencies and public bodies\\n\\n\\nNews\\nNews stories, speeches, letters and notices\\n\\n\\nGuidance and regulation\\nDetailed guidance, regulations and rules\\n\\n\\nResearch and statistics\\nReports, analysis and official statistics\\n\\n\\nPolicy papers and consultations\\nConsultations and strategy\\n\\n\\nTransparency\\nData, Freedom of Information releases and corporate reports\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n            Search\\n          \\n\\n\\n\\n\\nSearch GOV.UK\\n\\n\\n\\n\\n        Search\\n        \\n\\n\\n\\n\\n \\n\\n\\n\\n\\n\\n\\n \\n\\n\\n\\n\\n\\n\\n\\n\\n\\nRegister to vote\\n\\n          Register by 18 June to vote in the General Election on 4 July.\\n        \\n\\n\\n\\n\\n\\n\\n\\n\\n\\nHome\\n\\n\\nBusiness and industry\\n\\n\\nScience and innovation\\n\\n\\nArtificial intelligence\\n\\n\\nResearch on the cyber security of AI\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\nDepartment forScience, Innovation& Technology\\n\\n\\n\\n\\n\\n\\n\\n\\n    Research and analysis\\n  \\n\\n    AI cyber security survey - main report \\n  \\n\\nPublished 15 May 2024\\n\\n\\n\\n\\n\\n\\n      Contents\\n\\n\\n\\n\\n1. Executive summary\\n\\n\\n\\n2. Introduction\\n\\n\\n\\n3. Methodology\\n\\n\\n\\n4. AI usage\\n\\n\\n\\n5. Cyber security practices around AI\\n\\n\\n\\n6. General cyber security practices\\n\\n\\n\\n7. Appendix: Glossary\\n\\n\\n\\n\\nPrint this page\\n\\n\\n\\n\\n\\n\\n\\n\\n  © Crown copyright 2024\\n\\n\\n  This publication is licensed under the terms of the Open Government Licence v3.0 except where otherwise stated. To view this licence, visit nationalarchives.gov.uk/doc/open-government-licence/version/3 or write to the Information Policy Team, The National Archives, Kew, London TW9 4DU, or email: psi@nationalarchives.gov.uk.\\n\\n\\n  Where we have identified any third party copyright information you will need to obtain permission from the copyright holders concerned.\\n\\n\\n  This publication is available at https://www.gov.uk/government/publications/research-on-the-cyber-s ...

# %%
summarized_content = " "
for text in texts:
    response = model.generate_content(
        f"""You are a cyber security expert and an expert summarizer. The given text is from a website. Summarize in bulletin points.
        {text}
        """
    )
    summarized_content += response.text
    print(response.text)
# Out:
# ## AI Cyber Security Survey - Main Report Summary
#
# **1. Executive Summary:**
#
# **(i) Purpose:** The survey, commissioned by the Department for Science, Innovation and Technology (DSIT), aimed to understand AI usage and cyber security practices in UK businesses.
#
# **(ii) Methodology:** 350 interviews were conducted with businesses using or considering AI across nine sectors using Computer Assisted Telephone Interviewing (CATI).
#
# **(iii) Key Findings:**
#
# * **AI Adoption:**
#     * 68% of businesses are currently using AI, with 38% using natural language processing and generation.
#     * Over half of businesses have been using AI for at least a year, with 52% using machine learning for over 3 years.
#     * Most AI technologies are adopted through purchasing external software or ready-to-use systems.
# * **Cyber Security Practices:**
#     * Nearly half of businesses using AI (47%) have no specific cyber security practices in place for AI.
#     * 39% of businesses don't expect specific cyber security requirements to be built into AI models and systems.
#     * 90% of businesses have at least one governance or risk management arrangement in place for general cyber security.
#     * Over 75% of businesses have taken at least one measure to identify cyber security risks in the past year.
#
# **2. AI Usage:**
#
# * **Types of AI:** Natural language processing and generation is the most common AI technology used, followed by machine learning, computer vision, hardware related to AI, and robotic process automation.
# * **Adoption Methods:** Most businesses purchase external software or ready-to-use systems, with a smaller percentage developing AI in-house or outsourcing development.
# * **Reasons for Using AI:** Financial or cost savings are the primary reason for AI adoption, followed by document writing, speed and efficiency, and content generation.
#
# **3. Cyber Security Practices Around AI:**
#
# * **Specific AI Cyber Security Practices:** Only 40% of businesses currently using AI have specific cyber security practices in place for AI.
# * **Common Practices:** Firewalls for AI, ensuring personal data isn't shared with third parties, and employing external providers are common practices.
# * **Reasons for Lack of Specific Practices:** Businesses cite lack of consideration, AI not being used for sensitive data, and AI not being widely used enough as reasons for not adopting specific practices.
#
# **4. General Cyber Security Practices:**
#
# * **Governance and Risk Management:** 90% of businesses have at least one governance or risk management arrangement in place.
# * **Cyber Security Policies:** 72% have formal policies covering cyber security risks.
# * **Business Continuity Plans:** 67% have a Business Continuity Plan that covers cyber security.
# * **Critical Data Protection:** 64% have a written list of critical data, systems, or assets they want to protect.
# * **Cyber Security Standards:** 34% of businesses adhere to the Payment Card Industry Data Security Standard (PCI DSS), 29% to Cyber Essentials, and 18% to ISO 27000 Standard.
# * **Risk Identification Measures:** 78% of businesses have taken at least one measure to identify cyber security risks in the past year, with risk assessments and security monitoring tools being the most common.
#
# **5. Appendix: Glossary:**
#
# * **Artificial Intelligence (AI):** The development of systems that can perform tasks requiring human intelligence.
# * **Machine Learning:** Algorithms that learn from data to generate classifications, predictions, or patterns.
# * **Computer Vision/ Image Processing and Generation:** AI programming for manipulating digital images.
# * **Hardware Related to AI:** Edge Computing Chips, Quantum Hardware, ASICs, Neuromorphic Hardware, and FPGAs.
# * **Natural Language Processing and Generation:** AI programming for producing written or spoken narratives from data.
# * **Robotic Process Automation (RPA):** Software technology that emulates human actions interacting with digital systems.
